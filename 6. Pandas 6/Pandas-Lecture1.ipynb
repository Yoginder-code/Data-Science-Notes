# %% [markdown]
# ## Pandas
#   - **Installation of pandas** ✅
#     - Importing pandas✅
#     - Importing the dataset ✅
#     - Dataframe/Series✅
#
#   - **Basic ops on a DataFrame** ✅
#     - df.info()✅
#     - df.head()✅
#     - df.tail()✅
#     - df.shape()✅
#   - **Creating Dataframe from Scratch**✅
#
#   - **Basic ops on columns** ✅
#     - Different ways of accessing cols✅
#     - Check for Unique values✅
#
#     - Rename column
#     - Deleting col
#
#     - Creating new cols

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /Users/ritnil/Scaler-cohorts/mckinsey.csv
# 100%|███████████████████████████████████████| 83.8k/83.8k [00:00<00:00, 510kB/s]

# %%
df = pd.read_csv("/Users/ritnil/Scaler-cohorts/mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"] #recommended method 1 to access the column
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include="all")
# Out:
#             country        year    population continent     life_exp  \
# count          1704  1704.00000  1.704000e+03      1704  1704.000000
# unique          142         NaN           NaN         5          NaN
# top     Afghanistan         NaN           NaN    Africa          NaN
# freq             12         NaN           NaN       624          NaN
# mean            NaN  1979.50000  2.960121e+07       NaN    59.474439
# std             NaN    17.26533  1.061579e+08       NaN    12.917107
# min             NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%             NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%             NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%             NaN  1993.25000  1.958522e+07       NaN    70.845500
# max             NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#               gdp_cap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(-2)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1697     Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698     Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
#
# [1702 rows x 6 columns]

# %%
#Create our own dataframes

# %%
#1st method --> Row oriented

# %%
df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df1=pd.DataFrame([["Afghanistan",1952,8425333,"Asia",28.801,779.445314],
              ["Afghanistan",1957,9240934,"Asia",30.332,820.853030],
              ["Afghanistan",1962,10267083,"Asia",31.997,853.100710]],
            columns=["country","year","population","continent","life_exp","gdp_cap"])

# %%
df1
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df2=pd.DataFrame([["Afghanistan",1952,8425333,"Asia",28.801,779.445314]],
            columns=["country","year","population","continent","life_exp","gdp_cap"])
df2
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314

# %%
#2nd method --> Column oriented

# %%
df3=pd.DataFrame({"country":["Afghanistan","Afghanistan","Afghanistan"],
             "year":[1952,1957,1962],
             "population":[8425333,9240934,10267083],
             "continent":["Asia","Asia","Asia"],
             "life_exp":[28.801,30.332,31.997],
             "gdp_cap":[779.445314,820.853030,853.100710]})

# %%
df3
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df4=pd.DataFrame({"country":["Afghanistan","Afghanistan","Afghanistan","Afghanistan"],
             "year":[1952,1957,1962],
             "population":[8425333,9240934,10267083],
             "continent":["Asia","Asia","Asia"],
             "life_exp":[28.801,30.332,31.997],
             "gdp_cap":[779.445314,820.853030,853.100710]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df4=pd.DataFrame({"country":["Afghanistan","Afghanistan","Afghanistan","Afghanistan"],
#       2              "year":[1952,1957,1962],
#       3              "population":[8425333,9240934,10267083],
#       4              "continent":["Asia","Asia","Asia"],
#       5              "life_exp":[28.801,30.332,31.997],
#       6              "gdp_cap":[779.445314,820.853030,853.100710]})
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %% [markdown]
# ## Basic ops on columns**
#     - Different ways of accessing cols
#     - Check for Unique values
#
#     - Rename column
#     - Deleting col
#
#     - Creating new cols

# %%
df["country"] #recommended
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.country #not recommended
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() #Alternative method
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df["country"].nunique()
# Out:
# 142

# %%
df[["country","continent"]].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia

# %%
df[["country","continent"]]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %%
#df["country"]
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
#df[["country"]]
type(df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"].value_counts() #frequency of occurences
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df["continent"].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
df.rename({"country":"Country"},axis=1)
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"country":"Country"},axis=1) #method 1 to modify the column name

# %%
df.rename({"country":"Country"},axis=1,inplace=True) #method 2

# %%
df
# Out:
#           Country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"life_exp":"Life_exp",
                   "population":"Population",
                   "continent":"Continent"},inplace=True) #another way to update the column names

# %%
df
# Out:
#           Country  year  Population Continent  Life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Country', 'year', 'Population', 'Continent', 'Life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns[-1]
# Out:
# 'gdp_cap'

# %%
df.drop("Continent",axis=1)
# Out:
#           Country  year  Population  Life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           Country  year  Population Continent  Life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop(["Continent","year"],axis=1)
# Out:
#           Country  Population  Life_exp     gdp_cap
# 0     Afghanistan     8425333    28.801  779.445314
# 1     Afghanistan     9240934    30.332  820.853030
# 2     Afghanistan    10267083    31.997  853.100710
# 3     Afghanistan    11537966    34.020  836.197138
# 4     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1699     Zimbabwe     9216418    62.351  706.157306
# 1700     Zimbabwe    10704340    60.377  693.420786
# 1701     Zimbabwe    11404948    46.809  792.449960
# 1702     Zimbabwe    11926563    39.989  672.038623
# 1703     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
df.drop(columns=["Continent","year"])
# Out:
#           Country  Population  Life_exp     gdp_cap
# 0     Afghanistan     8425333    28.801  779.445314
# 1     Afghanistan     9240934    30.332  820.853030
# 2     Afghanistan    10267083    31.997  853.100710
# 3     Afghanistan    11537966    34.020  836.197138
# 4     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1699     Zimbabwe     9216418    62.351  706.157306
# 1700     Zimbabwe    10704340    60.377  693.420786
# 1701     Zimbabwe    11404948    46.809  792.449960
# 1702     Zimbabwe    11926563    39.989  672.038623
# 1703     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
df.drop(columns=["Continent"],inplace=True)

# %%
df
# Out:
#           Country  year  Population  Life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df["year+7"] = df["year"]+7

# %%
df
# Out:
#           Country  year  Population  Life_exp     gdp_cap  year+7
# 0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
# [1704 rows x 6 columns]

# %%
df["year + Gdp_cap"] =  ( df["year"] + df["Life_exp"] )*2

# %%
df
# Out:
#           Country  year  Population  Life_exp     gdp_cap  year+7  \
# 0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#       year + Gdp_cap
# 0           3961.602
# 1           3974.664
# 2           3987.994
# 3           4002.040
# 4           4016.176
# ...              ...
# ...

# %%
df["own"]=[i for i in range(1,1705)] #length of value should match length of index

# %%
df
# Out:
#           Country  year  Population  Life_exp     gdp_cap  year+7  \
# 0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#       year + Gdp_cap   own
# 0           3961.602     1
# 1           3974.664     2
# 2           3987.994     3
# 3           4002.040     4
# 4           4016.176     5
# ...
